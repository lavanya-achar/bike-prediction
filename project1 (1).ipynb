# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Lorddhaval/Dataset/patch-1/Bike%20Prices.csv')

# %%
df.head()
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000              30490
# 1      35000              32000
# 2      10000              37675
# 3      43000              42859
# 4      35000              42859

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     625.000000   625.000000     625.000000         625.000000
# mean    58340.276800  2014.803200   32704.651200       86054.648000
# std     53186.944553     3.020441   45508.553232       61173.244185
# min      6000.000000  2001.000000     380.000000       30490.000000
# 25%     30000.000000  2013.000000   13125.000000       54852.000000
# 50%     45000.000000  2015.000000   25000.000000       72532.000000
# 75%     65000.000000  2017.000000   40000.000000       87000.000000
# max    760000.000000  2020.000000  585659.000000      752020.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              625 non-null    object
#  1   Model              625 non-null    object
#  2   Selling_Price      625 non-null    int64
#  3   Year               625 non-null    int64
#  4   Seller_Type        625 non-null    object
#  5   Owner              625 non-null    object
#  6   KM_Driven          625 non-null    int64
#  7   Ex_Showroom_Price  625 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 39.2+ KB

# %%
df[['Brand']].value_counts()
# Out:
# Brand
# Honda       170
# Bajaj       143
# Hero        108
# Yamaha       94
# Royal        40
# TVS          23
# Suzuki       18
# KTM           6
# Mahindra      6
# Kawasaki      4
# UM            3
# Activa        3
# Vespa         2
# BMW           1
# Hyosung       1
# Harley        1
# Benelli       1
# Yo            1
# Name: count, dtype: int64

# %%
df[['Model']].value_counts()
# Out:
# Model
# Honda Activa [2000-2015]                      23
# Honda CB Hornet 160R                          22
# Bajaj Pulsar 180                              20
# Bajaj Discover 125                            16
# Yamaha FZ S V 2.0                             16
#                                               ..
# Royal Enfield Continental GT [2013 - 2018]     1
# Royal Enfield Classic Stealth Black            1
# Royal Enfield Classic Squadron Blue            1
# Royal Enfield Classic Signals                  1
# Yo Style                                       1
# Name: count, Length: 182, dtype: int64

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %%
df.replace({'Seller_Type':{'Individual':0, 'Dealer':1}},inplace=True)

# %%
df.replace({'Owner':{'1st owner':0, '2nd owner' :1, '3rd owner':2, '4th owner':3}},inplace=True)

# %%
y = df['Selling_Price']
     

y.shape
     


y
# Out:
# 0       30000
# 1       18000
# 2       20000
# 3       25000
# 4       24999
#         ...
# 620    300000
# 621    330000
# 622    300000
# 623    425000
# 624    760000
# Name: Selling_Price, Length: 625, dtype: int64

# %%
X = df[['Year', 'Seller_Type', 'Owner' ,'KM_Driven','Ex_Showroom_Price']]
     

X.shape
     
X
# Out:
#      Year  Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 0    2017            0      0       8000              30490
# 1    2017            0      0      35000              32000
# 2    2011            0      0      10000              37675
# 3    2010            0      0      43000              42859
# 4    2012            0      1      35000              42859
# ..    ...          ...    ...        ...                ...
# 620  2016            0      0       9800             360000
# 621  2014            0      3       6500             534000
# 622  2011            0      0      12000             589000
# 623  2017            0      1      13600             599000
# 624  2019            0      0       2800             752020
#
# [625 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
     

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=222529)
     

X_train.shape , X_test.shape, y_train.shape, y_test.shape
# Out:
# ((437, 5), (188, 5), (437,), (188,))

# %%
from sklearn.linear_model import LinearRegression
     

lr = LinearRegression()
     

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
     

y_pred.shape
     
(188,)

y_pred
# Out:
# array([ 31759.32474383,  55237.05274615,  60121.03586233,  30803.1857746 ,
#         53237.76993019, 108635.64688663,  34630.69688209,  50827.86201476,
#         53708.62467871,  60942.38885847,  66293.42015989,  35174.51944078,
#         27826.51406498,  37096.75105982, 217395.29408874, 108594.63042175,
#         50066.33785157,  81313.93838597, 142903.56624853,   4100.3418088 ,
#        122830.55392247,  35274.78191049,  39538.13632231,  50050.81338777,
#        162983.77523041,  29269.22842952,  94944.90356801, 106158.04967606,
#         49577.2079869 , 125708.50476882,  61472.10323631,  78676.98557529,
#        142237.10124745,  51945.53945341,  47393.61800111,  21859.84796745,
#         41022.10132051,  39674.85787191,  -4712.43036744,  21997.96439485,
#         55037.53488094, 146589.57684366,  31161.06992524,  60137.17204344,
#         49636.25737638,  79316.18985602,  73179.72040921, 145826.478221  ,
#         78743.89223442,  24872.56849916,  23999.97424242, 168031.146911  ,
#        105251.62085872, 116292.29502455,   5091.5023894 ,  38769.23290855,
#         35004.17426512,  72543.56137837,  36389.89994772,  23143.48372216,
#         78640.55823338, 118743.57492123, -13162.72833037,  84773.39023526,
#         26645.54021082,  40628.29354544,  15440.80058507,  37133.18089853,
#          8172.5980282 ,  45392.6461894 ,  19890.32542275,  80623.09496027,
#         58602.20249265,  91507.50908423,  35229.20806062,  45891.9389948 ,
#         34044.81048397,   3600.75441591,  46020.14409661,  36677.99042165,
#         53491.41911625, 130923.31239193,  58468.31099413,  60095.99830681,
#         70171.81701451,  66001.18633928, 136703.74323942, 157066.73335274,
#         44923.06293712,  29717.99296708,  37612.22143333,  33480.92516773,
#         24168.87111786, 122782.24564161, 134897.65876171,  24907.07230452,
#         24003.68750552,  27301.52190591,  26499.92102351,  -2213.35511073,
#         83752.11724601,  58624.90542187, 111075.27016774,  18486.17869977,
#         49608.46217527,  79756.71770838,  49592.20265484,  90007.59725393,
#        152408.76088064,  28443.26080349,  32947.69057072,  28681.4244742 ,
#         53702.5481654 ,  20384.38002126,  38355.11177157,  35068.36310488,
#         35270.2245255 ,  58505.74227183,  -8778.75512923,  70244.7351743 ,
#         65826.01787187,  32943.13318574,  62181.08917352,  55602.25304482,
#         43075.12291358,  53669.51969497, -13073.43975571, -26400.32677153,
#         33095.41132427,  41201.5651453 ,  21493.47812261,  61173.7548095 ,
#        156138.4302587 , 137238.96616337,  59369.22272569,  28015.62503676,
#         53298.26707249,  50041.6986178 ,  49558.78183161,  39535.05162337,
#         64919.02278856,  40557.65835691,  12566.59747631,  51565.92844397,
#         20366.15048131,  54664.81197275,  54012.09499857,  45822.05909166,
#         41954.57051826,  50114.31678384,  20539.61034908,  35165.40467081,
#        265380.99114602,  47987.97145809,  39978.57594087,  32137.94333431,
#         44018.21712077,  73268.25252433,  50066.12810929,  35229.20806062,
#         20941.05981352,  53567.64875093,  28482.29209116,  12461.00391514,
#         77622.33196384,  19090.16553195,  27267.43305637,  33835.78367433,
#        471723.46080887,  48329.67930926,  72604.5819717 , 137728.45353148,
#         25843.52719888,  36608.11051851,  51924.17254408,  54955.66601948,
#         19918.56457561,  23175.84191914,  31222.96601951,  51972.49904948,
#         48731.29931533,  17586.36862172,  57203.04393879,  51100.27945306,
#         35223.13154731,  57046.05316629,  26025.4564876 ,  45434.54009152])

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score
     

mean_squared_error(y_test,y_pred)
# Out:
# 357601048.3023488

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 11805.735959425707

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8332147278404065

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Predicted Price") 
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df_new = df.sample(1)
     

df_new
# Out:
#     Brand                     Model  Selling_Price  Year  Seller_Type  Owner  \
# 49  Honda  Honda Activa [2000-2015]          30000  2014            0      0
#
#     KM_Driven  Ex_Showroom_Price
# 49      52000              50267

# %%
X_new = df_new.drop(['Brand', 'Model', 'Selling_Price'], axis = 1)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([27268.10108267])
